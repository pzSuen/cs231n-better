# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720925453725e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447646e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732093

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302976
# iteration 100 / 1000: loss 2.302487
# iteration 200 / 1000: loss 2.298445
# iteration 300 / 1000: loss 2.272842
# iteration 400 / 1000: loss 2.160314
# iteration 500 / 1000: loss 2.144013
# iteration 600 / 1000: loss 2.070936
# iteration 700 / 1000: loss 1.976521
# iteration 800 / 1000: loss 1.951775
# iteration 900 / 1000: loss 1.958305
# Validation accuracy:  0.28

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

'''
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
'''

def show_net_weights(net):
#     print(net.params['W1'].shape)
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)
# 输出共50个，因为隐藏层结点数为50
# Out:
# (49000, 3072)
# (3072, 50)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# from copy import deepcopy 
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

learning_rates=[1e-4,1e-3,9e-3,1e-2]
batch_sizes=[64,128,256,512]
# learning_rate_dacay=[0.95,0.90,0.85,0.80]
regs=[0.25,0,35,0,45,0.5]

best_acc=0.0
best_lr=0.0
best_bs=0.0
best_reg=0.0

for lr in learning_rates:
    for bs in batch_sizes:
        for reg in regs:
            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                        num_iters=1000, batch_size=bs,
                        learning_rate=lr , learning_rate_decay=0.95,
                        reg=reg, verbose=True)

            # Predict on the validation set
            val_acc = (net.predict(X_val) == y_val).mean()
            print('learning_rate: ',lr,' ;batch_size :',bs,'reg :',reg,' ;Validation accuracy: ', val_acc)
            
            
            if val_acc>best_acc:
                best_lr=lr
                best_bs=bs
                best_reg=reg
print("Best params : ",'learning_rate: ',lr,' ;batch_size :'+bs,'reg :',reg,' ;Validation accuracy: ', val_acc)


#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 1000: loss 2.302998
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.299046
# iteration 300 / 1000: loss 2.283302
# iteration 400 / 1000: loss 2.228093
# iteration 500 / 1000: loss 2.145624
# iteration 600 / 1000: loss 2.085539
# iteration 700 / 1000: loss 2.137207
# iteration 800 / 1000: loss 1.868120
# iteration 900 / 1000: loss 2.055299
# learning_rate:  0.0001  ;batch_size : 64 reg : 0.25  ;Validation accuracy:  0.298
# iteration 0 / 1000: loss 1.969121
# iteration 100 / 1000: loss 1.862052
# iteration 200 / 1000: loss 1.850906
# iteration 300 / 1000: loss 1.703142
# iteration 400 / 1000: loss 1.678005
# iteration 500 / 1000: loss 1.935479
# iteration 600 / 1000: loss 1.798165
# iteration 700 / 1000: loss 1.769990
# iteration 800 / 1000: loss 1.861352
# iteration 900 / 1000: loss 1.752271
# learning_rate:  0.0001  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.376
# iteration 0 / 1000: loss 3.403759
# iteration 100 / 1000: loss 2.487109
# iteration 200 / 1000: loss 2.422030
# iteration 300 / 1000: loss 2.217196
# iteration 400 / 1000: loss 2.292117
# iteration 500 / 1000: loss 2.243890
# iteration 600 / 1000: loss 2.209358
# iteration 700 / 1000: loss 2.276446
# iteration 800 / 1000: loss 2.238560
# iteration 900 / 1000: loss 2.313120
# learning_rate:  0.0001  ;batch_size : 64 reg : 35  ;Validation accuracy:  0.235
# iteration 0 / 1000: loss 2.182945
# iteration 100 / 1000: loss 2.073229
# iteration 200 / 1000: loss 2.156668
# iteration 300 / 1000: loss 2.048252
# iteration 400 / 1000: loss 2.186107
# iteration 500 / 1000: loss 1.963765
# iteration 600 / 1000: loss 2.003418
# iteration 700 / 1000: loss 1.977572
# iteration 800 / 1000: loss 1.797234
# iteration 900 / 1000: loss 1.734077
# learning_rate:  0.0001  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.346
# iteration 0 / 1000: loss 3.606181
# iteration 100 / 1000: loss 2.478295
# iteration 200 / 1000: loss 2.339899
# iteration 300 / 1000: loss 2.292016
# iteration 400 / 1000: loss 2.343360
# iteration 500 / 1000: loss 2.235518
# iteration 600 / 1000: loss 2.294482
# iteration 700 / 1000: loss 2.293334
# iteration 800 / 1000: loss 2.301300
# iteration 900 / 1000: loss 2.312845
# learning_rate:  0.0001  ;batch_size : 64 reg : 45  ;Validation accuracy:  0.207
# iteration 0 / 1000: loss 2.229774
# iteration 100 / 1000: loss 2.207239
# iteration 200 / 1000: loss 2.114331
# iteration 300 / 1000: loss 1.965338
# iteration 400 / 1000: loss 2.100490
# iteration 500 / 1000: loss 1.964539
# iteration 600 / 1000: loss 1.951211
# iteration 700 / 1000: loss 1.908330
# iteration 800 / 1000: loss 1.877225
# iteration 900 / 1000: loss 1.743143
# learning_rate:  0.0001  ;batch_size : 64 reg : 0.5  ;Validation accuracy:  0.315
# iteration 0 / 1000: loss 1.972473
# iteration 100 / 1000: loss 1.855441
# iteration 200 / 1000: loss 1.819927
# iteration 300 / 1000: loss 1.840554
# iteration 400 / 1000: loss 1.829182
# iteration 500 / 1000: loss 1.874227
# iteration 600 / 1000: loss 1.785682
# iteration 700 / 1000: loss 1.766835
# iteration 800 / 1000: loss 1.751826
# iteration 900 / 1000: loss 1.680021
# learning_rate:  0.0001  ;batch_size : 128 reg : 0.25  ;Validation accuracy:  0.374
# iteration 0 / 1000: loss 1.748177
# iteration 100 / 1000: loss 1.753589
# iteration 200 / 1000: loss 1.755195
# iteration 300 / 1000: loss 1.683152
# iteration 400 / 1000: loss 1.588821
# iteration 500 / 1000: loss 1.711399
# iteration 600 / 1000: loss 1.689939
# iteration 700 / 1000: loss 1.622588
# iteration 800 / 1000: loss 1.579638
# iteration 900 / 1000: loss 1.718180
# learning_rate:  0.0001  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.414
# iteration 0 / 1000: loss 4.432310
# iteration 100 / 1000: loss 2.801021
# iteration 200 / 1000: loss 2.414381
# iteration 300 / 1000: loss 2.326650
# iteration 400 / 1000: loss 2.298092
# iteration 500 / 1000: loss 2.276957
# iteration 600 / 1000: loss 2.288402
# iteration 700 / 1000: loss 2.271575
# iteration 800 / 1000: loss 2.275945
# iteration 900 / 1000: loss 2.248191
# learning_rate:  0.0001  ;batch_size : 128 reg : 35  ;Validation accuracy:  0.231
# iteration 0 / 1000: loss 2.164153
# iteration 100 / 1000: loss 2.051861
# iteration 200 / 1000: loss 2.083491
# iteration 300 / 1000: loss 1.998171
# iteration 400 / 1000: loss 2.042091
# iteration 500 / 1000: loss 1.944457
# iteration 600 / 1000: loss 1.992966
# iteration 700 / 1000: loss 1.900061
# iteration 800 / 1000: loss 1.919550
# iteration 900 / 1000: loss 1.794827
# learning_rate:  0.0001  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.338
# iteration 0 / 1000: loss 3.389148
# iteration 100 / 1000: loss 2.472986
# iteration 200 / 1000: loss 2.377671
# iteration 300 / 1000: loss 2.334027
# iteration 400 / 1000: loss 2.296035
# iteration 500 / 1000: loss 2.293928
# iteration 600 / 1000: loss 2.270359
# iteration 700 / 1000: loss 2.317474
# iteration 800 / 1000: loss 2.282788
# iteration 900 / 1000: loss 2.292412
# learning_rate:  0.0001  ;batch_size : 128 reg : 45  ;Validation accuracy:  0.196
# iteration 0 / 1000: loss 2.206498
# iteration 100 / 1000: loss 2.145637
# iteration 200 / 1000: loss 2.034143
# iteration 300 / 1000: loss 2.046394
# iteration 400 / 1000: loss 1.983246
# iteration 500 / 1000: loss 2.004229
# iteration 600 / 1000: loss 1.976262
# iteration 700 / 1000: loss 1.810658
# iteration 800 / 1000: loss 1.864692
# iteration 900 / 1000: loss 1.932696
# learning_rate:  0.0001  ;batch_size : 128 reg : 0.5  ;Validation accuracy:  0.325
# iteration 0 / 1000: loss 1.975733
# iteration 100 / 1000: loss 1.876843
# iteration 200 / 1000: loss 1.916428
# iteration 300 / 1000: loss 1.817530
# iteration 400 / 1000: loss 1.858872
# iteration 500 / 1000: loss 1.826372
# iteration 600 / 1000: loss 1.868363
# iteration 700 / 1000: loss 1.824000
# iteration 800 / 1000: loss 1.750707
# iteration 900 / 1000: loss 1.713240
# learning_rate:  0.0001  ;batch_size : 256 reg : 0.25  ;Validation accuracy:  0.376
# iteration 0 / 1000: loss 1.663165
# iteration 100 / 1000: loss 1.748763
# iteration 200 / 1000: loss 1.772496
# iteration 300 / 1000: loss 1.727917
# iteration 400 / 1000: loss 1.735744
# iteration 500 / 1000: loss 1.728335
# iteration 600 / 1000: loss 1.595666
# iteration 700 / 1000: loss 1.683815
# iteration 800 / 1000: loss 1.720734
# iteration 900 / 1000: loss 1.620780
# learning_rate:  0.0001  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.417
# iteration 0 / 1000: loss 4.446784
# iteration 100 / 1000: loss 2.756440
# iteration 200 / 1000: loss 2.446232
# iteration 300 / 1000: loss 2.310282
# iteration 400 / 1000: loss 2.291722
# iteration 500 / 1000: loss 2.270828
# iteration 600 / 1000: loss 2.265179
# iteration 700 / 1000: loss 2.257552
# iteration 800 / 1000: loss 2.281965
# iteration 900 / 1000: loss 2.259240
# learning_rate:  0.0001  ;batch_size : 256 reg : 35  ;Validation accuracy:  0.237
# iteration 0 / 1000: loss 2.157537
# iteration 100 / 1000: loss 2.072222
# iteration 200 / 1000: loss 2.020021
# iteration 300 / 1000: loss 2.009299
# iteration 400 / 1000: loss 1.863160
# iteration 500 / 1000: loss 1.949300
# iteration 600 / 1000: loss 1.881318
# iteration 700 / 1000: loss 1.871005
# iteration 800 / 1000: loss 1.778597
# iteration 900 / 1000: loss 1.791562
# learning_rate:  0.0001  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.348
# iteration 0 / 1000: loss 3.399882
# iteration 100 / 1000: loss 2.467368
# iteration 200 / 1000: loss 2.318780
# iteration 300 / 1000: loss 2.307811
# iteration 400 / 1000: loss 2.292016
# iteration 500 / 1000: loss 2.293671
# iteration 600 / 1000: loss 2.300195
# iteration 700 / 1000: loss 2.292327
# iteration 800 / 1000: loss 2.289050
# iteration 900 / 1000: loss 2.281140
# learning_rate:  0.0001  ;batch_size : 256 reg : 45  ;Validation accuracy:  0.199
# iteration 0 / 1000: loss 2.238278
# iteration 100 / 1000: loss 2.162174
# iteration 200 / 1000: loss 2.076236
# iteration 300 / 1000: loss 2.116151
# iteration 400 / 1000: loss 2.063138
# iteration 500 / 1000: loss 1.957010
# iteration 600 / 1000: loss 1.952166
# iteration 700 / 1000: loss 1.857256
# iteration 800 / 1000: loss 1.909263
# iteration 900 / 1000: loss 1.875063
# learning_rate:  0.0001  ;batch_size : 256 reg : 0.5  ;Validation accuracy:  0.322
# iteration 0 / 1000: loss 1.937496
# iteration 100 / 1000: loss 1.855720
# iteration 200 / 1000: loss 1.868155
# iteration 300 / 1000: loss 1.826509
# iteration 400 / 1000: loss 1.794012
# iteration 500 / 1000: loss 1.857948
# iteration 600 / 1000: loss 1.833720
# iteration 700 / 1000: loss 1.760432
# iteration 800 / 1000: loss 1.753842
# iteration 900 / 1000: loss 1.695913
# learning_rate:  0.0001  ;batch_size : 512 reg : 0.25  ;Validation accuracy:  0.378
# iteration 0 / 1000: loss 1.785236
# iteration 100 / 1000: loss 1.756515
# iteration 200 / 1000: loss 1.716586
# iteration 300 / 1000: loss 1.715238
# iteration 400 / 1000: loss 1.711578
# iteration 500 / 1000: loss 1.699289
# iteration 600 / 1000: loss 1.649768
# iteration 700 / 1000: loss 1.683632
# iteration 800 / 1000: loss 1.633016
# iteration 900 / 1000: loss 1.625805
# learning_rate:  0.0001  ;batch_size : 512 reg : 0  ;Validation accuracy:  0.405
# iteration 0 / 1000: loss 4.295327
# iteration 100 / 1000: loss 2.753565
# iteration 200 / 1000: loss 2.409276
# iteration 300 / 1000: loss 2.342235
# iteration 400 / 1000: loss 2.295660
# iteration 500 / 1000: loss 2.283356
# iteration 600 / 1000: loss 2.261160
# iteration 700 / 1000: loss 2.298348
# iteration 800 / 1000: loss 2.281224
# iteration 900 / 1000: loss 2.278725
# learning_rate:  0.0001  ;batch_size : 512 reg : 35  ;Validation accuracy:  0.239
# iteration 0 / 1000: loss 2.187818
# iteration 100 / 1000: loss 2.067996
# iteration 200 / 1000: loss 2.005741
# iteration 300 / 1000: loss 1.958158
# iteration 400 / 1000: loss 1.938803
# iteration 500 / 1000: loss 1.951004
# iteration 600 / 1000: loss 1.832130
# iteration 700 / 1000: loss 1.913583
# iteration 800 / 1000: loss 1.805050
# iteration 900 / 1000: loss 1.822131
# learning_rate:  0.0001  ;batch_size : 512 reg : 0  ;Validation accuracy:  0.345
# iteration 0 / 1000: loss 3.394238
# iteration 100 / 1000: loss 2.468123
# iteration 200 / 1000: loss 2.343937
# iteration 300 / 1000: loss 2.316073
# iteration 400 / 1000: loss 2.289074
# iteration 500 / 1000: loss 2.305666
# iteration 600 / 1000: loss 2.305893
# iteration 700 / 1000: loss 2.279448
# iteration 800 / 1000: loss 2.290052
# iteration 900 / 1000: loss 2.284779
# learning_rate:  0.0001  ;batch_size : 512 reg : 45  ;Validation accuracy:  0.206
# iteration 0 / 1000: loss 2.242343
# iteration 100 / 1000: loss 2.145282
# iteration 200 / 1000: loss 2.056899
# iteration 300 / 1000: loss 2.055164
# iteration 400 / 1000: loss 2.014543
# iteration 500 / 1000: loss 2.027503
# iteration 600 / 1000: loss 1.926891
# iteration 700 / 1000: loss 1.946723
# iteration 800 / 1000: loss 1.959397
# iteration 900 / 1000: loss 1.895078
# learning_rate:  0.0001  ;batch_size : 512 reg : 0.5  ;Validation accuracy:  0.32
# iteration 0 / 1000: loss 1.751242
# iteration 100 / 1000: loss 1.747423
# iteration 200 / 1000: loss 1.909054
# iteration 300 / 1000: loss 1.733205
# iteration 400 / 1000: loss 1.670480
# iteration 500 / 1000: loss 1.672446
# iteration 600 / 1000: loss 1.728007
# iteration 700 / 1000: loss 1.585925
# iteration 800 / 1000: loss 1.694277
# iteration 900 / 1000: loss 1.509036
# learning_rate:  0.001  ;batch_size : 64 reg : 0.25  ;Validation accuracy:  0.411
# iteration 0 / 1000: loss 1.496457
# iteration 100 / 1000: loss 1.765448
# iteration 200 / 1000: loss 1.506853
# iteration 300 / 1000: loss 1.467912
# iteration 400 / 1000: loss 1.641824
# iteration 500 / 1000: loss 1.265261
# iteration 600 / 1000: loss 1.557705
# iteration 700 / 1000: loss 1.475454
# iteration 800 / 1000: loss 1.586124
# iteration 900 / 1000: loss 1.397596
# learning_rate:  0.001  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.444
# iteration 0 / 1000: loss 19.367466
# iteration 100 / 1000: loss 2.310364
# iteration 200 / 1000: loss 2.305550
# iteration 300 / 1000: loss 2.246066
# iteration 400 / 1000: loss 2.248852
# iteration 500 / 1000: loss 2.244236
# iteration 600 / 1000: loss 2.299650
# iteration 700 / 1000: loss 2.265784
# iteration 800 / 1000: loss 2.239722
# iteration 900 / 1000: loss 2.279175
# learning_rate:  0.001  ;batch_size : 64 reg : 35  ;Validation accuracy:  0.179
# iteration 0 / 1000: loss 2.159532
# iteration 100 / 1000: loss 1.971552
# iteration 200 / 1000: loss 1.790605
# iteration 300 / 1000: loss 1.864702
# iteration 400 / 1000: loss 1.592332
# iteration 500 / 1000: loss 1.713298
# iteration 600 / 1000: loss 1.549352
# iteration 700 / 1000: loss 1.515203
# iteration 800 / 1000: loss 1.695946
# iteration 900 / 1000: loss 1.384367
# learning_rate:  0.001  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.437
# iteration 0 / 1000: loss 12.762498
# iteration 100 / 1000: loss 2.303681
# iteration 200 / 1000: loss 2.305776
# iteration 300 / 1000: loss 2.289121
# iteration 400 / 1000: loss 2.288651
# iteration 500 / 1000: loss 2.307570
# iteration 600 / 1000: loss 2.335440
# iteration 700 / 1000: loss 2.310853
# iteration 800 / 1000: loss 2.323221
# iteration 900 / 1000: loss 2.299715
# learning_rate:  0.001  ;batch_size : 64 reg : 45  ;Validation accuracy:  0.212
# iteration 0 / 1000: loss 2.245604
# iteration 100 / 1000: loss 2.035951
# iteration 200 / 1000: loss 1.902795
# iteration 300 / 1000: loss 1.819380
# iteration 400 / 1000: loss 1.770909
# iteration 500 / 1000: loss 1.789308
# iteration 600 / 1000: loss 1.882102
# iteration 700 / 1000: loss 1.733815
# iteration 800 / 1000: loss 1.409833
# iteration 900 / 1000: loss 1.694278
# learning_rate:  0.001  ;batch_size : 64 reg : 0.5  ;Validation accuracy:  0.392
# iteration 0 / 1000: loss 1.726474
# iteration 100 / 1000: loss 1.673213
# iteration 200 / 1000: loss 1.448540
# iteration 300 / 1000: loss 1.599002
# iteration 400 / 1000: loss 1.436886
# iteration 500 / 1000: loss 1.565788
# iteration 600 / 1000: loss 1.594716
# iteration 700 / 1000: loss 1.446531
# iteration 800 / 1000: loss 1.636668
# iteration 900 / 1000: loss 1.523545
# learning_rate:  0.001  ;batch_size : 128 reg : 0.25  ;Validation accuracy:  0.464
# iteration 0 / 1000: loss 1.424037
# iteration 100 / 1000: loss 1.351048
# iteration 200 / 1000: loss 1.756290
# iteration 300 / 1000: loss 1.278749
# iteration 400 / 1000: loss 1.501739
# iteration 500 / 1000: loss 1.428093
# iteration 600 / 1000: loss 1.328012
# iteration 700 / 1000: loss 1.315450
# iteration 800 / 1000: loss 1.409121
# iteration 900 / 1000: loss 1.377694
# learning_rate:  0.001  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.487
# iteration 0 / 1000: loss 21.564546
# iteration 100 / 1000: loss 2.245676
# iteration 200 / 1000: loss 2.269346
# iteration 300 / 1000: loss 2.258764
# iteration 400 / 1000: loss 2.269410
# iteration 500 / 1000: loss 2.268808
# iteration 600 / 1000: loss 2.234376
# iteration 700 / 1000: loss 2.297922
# iteration 800 / 1000: loss 2.243593
# iteration 900 / 1000: loss 2.252951
# learning_rate:  0.001  ;batch_size : 128 reg : 35  ;Validation accuracy:  0.218
# iteration 0 / 1000: loss 2.175687
# iteration 100 / 1000: loss 2.034881
# iteration 200 / 1000: loss 1.781952
# iteration 300 / 1000: loss 1.631965
# iteration 400 / 1000: loss 1.829604
# iteration 500 / 1000: loss 1.611463
# iteration 600 / 1000: loss 1.701804
# iteration 700 / 1000: loss 1.513762
# iteration 800 / 1000: loss 1.460723
# iteration 900 / 1000: loss 1.551267
# learning_rate:  0.001  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.452
# iteration 0 / 1000: loss 12.247368
# iteration 100 / 1000: loss 2.297545
# iteration 200 / 1000: loss 2.278597
# iteration 300 / 1000: loss 2.266706
# iteration 400 / 1000: loss 2.284459
# iteration 500 / 1000: loss 2.288708
# iteration 600 / 1000: loss 2.276718
# iteration 700 / 1000: loss 2.292771
# iteration 800 / 1000: loss 2.287824
# iteration 900 / 1000: loss 2.309620
# learning_rate:  0.001  ;batch_size : 128 reg : 45  ;Validation accuracy:  0.179
# iteration 0 / 1000: loss 2.187044
# iteration 100 / 1000: loss 1.976471
# iteration 200 / 1000: loss 1.842006
# iteration 300 / 1000: loss 1.658537
# iteration 400 / 1000: loss 1.836940
# iteration 500 / 1000: loss 1.825011
# iteration 600 / 1000: loss 1.684771
# iteration 700 / 1000: loss 1.530720
# iteration 800 / 1000: loss 1.478264
# iteration 900 / 1000: loss 1.585399
# learning_rate:  0.001  ;batch_size : 128 reg : 0.5  ;Validation accuracy:  0.451
# iteration 0 / 1000: loss 1.674444
# iteration 100 / 1000: loss 1.625339
# iteration 200 / 1000: loss 1.494118
# iteration 300 / 1000: loss 1.567417
# iteration 400 / 1000: loss 1.459660
# iteration 500 / 1000: loss 1.518695
# iteration 600 / 1000: loss 1.332091
# iteration 700 / 1000: loss 1.590399
# iteration 800 / 1000: loss 1.600085
# iteration 900 / 1000: loss 1.552752
# learning_rate:  0.001  ;batch_size : 256 reg : 0.25  ;Validation accuracy:  0.494
# iteration 0 / 1000: loss 1.376058
# iteration 100 / 1000: loss 1.372528
# iteration 200 / 1000: loss 1.363680
# iteration 300 / 1000: loss 1.368027
# iteration 400 / 1000: loss 1.323485
# iteration 500 / 1000: loss 1.452775
# iteration 600 / 1000: loss 1.376360
# iteration 700 / 1000: loss 1.450332
# iteration 800 / 1000: loss 1.342467
# iteration 900 / 1000: loss 1.243352
# learning_rate:  0.001  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.469
# iteration 0 / 1000: loss 23.659586
# iteration 100 / 1000: loss 2.270179
# iteration 200 / 1000: loss 2.268469
# iteration 300 / 1000: loss 2.291076
# iteration 400 / 1000: loss 2.266763
# iteration 500 / 1000: loss 2.251441
# iteration 600 / 1000: loss 2.269703
# iteration 700 / 1000: loss 2.256689
# iteration 800 / 1000: loss 2.262789
# iteration 900 / 1000: loss 2.256504
# learning_rate:  0.001  ;batch_size : 256 reg : 35  ;Validation accuracy:  0.225
# iteration 0 / 1000: loss 2.154242
# iteration 100 / 1000: loss 1.922772
# iteration 200 / 1000: loss 1.853085
# iteration 300 / 1000: loss 1.728052
# iteration 400 / 1000: loss 1.647298
# iteration 500 / 1000: loss 1.527856
# iteration 600 / 1000: loss 1.632320
# iteration 700 / 1000: loss 1.651254
# iteration 800 / 1000: loss 1.442557
# iteration 900 / 1000: loss 1.484557
# learning_rate:  0.001  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.476
# iteration 0 / 1000: loss 12.786654
# iteration 100 / 1000: loss 2.296293
# iteration 200 / 1000: loss 2.278062
# iteration 300 / 1000: loss 2.291500
# iteration 400 / 1000: loss 2.300229
# iteration 500 / 1000: loss 2.280898
# iteration 600 / 1000: loss 2.288119
# iteration 700 / 1000: loss 2.275092
# iteration 800 / 1000: loss 2.284236
# iteration 900 / 1000: loss 2.288839
# learning_rate:  0.001  ;batch_size : 256 reg : 45  ;Validation accuracy:  0.199
# iteration 0 / 1000: loss 2.220310
# iteration 100 / 1000: loss 1.959503
# iteration 200 / 1000: loss 1.848236
# iteration 300 / 1000: loss 1.799196
# iteration 400 / 1000: loss 1.707124
# iteration 500 / 1000: loss 1.656811
# iteration 600 / 1000: loss 1.688433
# iteration 700 / 1000: loss 1.701492
# iteration 800 / 1000: loss 1.647456
# iteration 900 / 1000: loss 1.585548
# learning_rate:  0.001  ;batch_size : 256 reg : 0.5  ;Validation accuracy:  0.458
# iteration 0 / 1000: loss 1.573464
# iteration 100 / 1000: loss 1.509084
# iteration 200 / 1000: loss 1.458401
# iteration 300 / 1000: loss 1.560604
# iteration 400 / 1000: loss 1.551750
# iteration 500 / 1000: loss 1.495108
# iteration 600 / 1000: loss 1.486354
# iteration 700 / 1000: loss 1.497166
# iteration 800 / 1000: loss 1.478030
# iteration 900 / 1000: loss 1.419370
# learning_rate:  0.001  ;batch_size : 512 reg : 0.25  ;Validation accuracy:  0.49
# iteration 0 / 1000: loss 1.408643
# iteration 100 / 1000: loss 1.421211
# iteration 200 / 1000: loss 1.299277
# iteration 300 / 1000: loss 1.300963
# iteration 400 / 1000: loss 1.364155
# iteration 500 / 1000: loss 1.281403
# iteration 600 / 1000: loss 1.228194
# iteration 700 / 1000: loss 1.208470
# iteration 800 / 1000: loss 1.262844
# iteration 900 / 1000: loss 1.234720
# learning_rate:  0.001  ;batch_size : 512 reg : 0  ;Validation accuracy:  0.527
# iteration 0 / 1000: loss 24.596642
# iteration 100 / 1000: loss 2.272723
# iteration 200 / 1000: loss 2.274407
# iteration 300 / 1000: loss 2.276156
# iteration 400 / 1000: loss 2.290279
# iteration 500 / 1000: loss 2.280304
# iteration 600 / 1000: loss 2.253678
# iteration 700 / 1000: loss 2.264726
# iteration 800 / 1000: loss 2.258141
# iteration 900 / 1000: loss 2.290606
# learning_rate:  0.001  ;batch_size : 512 reg : 35  ;Validation accuracy:  0.228
# iteration 0 / 1000: loss 2.206518
# iteration 100 / 1000: loss 1.929087
# iteration 200 / 1000: loss 1.833542
# iteration 300 / 1000: loss 1.765762
# iteration 400 / 1000: loss 1.579577
# iteration 500 / 1000: loss 1.519151
# iteration 600 / 1000: loss 1.549309
# iteration 700 / 1000: loss 1.608143
# iteration 800 / 1000: loss 1.503380
# iteration 900 / 1000: loss 1.398875
# learning_rate:  0.001  ;batch_size : 512 reg : 0  ;Validation accuracy:  0.489
# iteration 0 / 1000: loss 13.060202
# iteration 100 / 1000: loss 2.292561
# iteration 200 / 1000: loss 2.304609
# iteration 300 / 1000: loss 2.293955
# iteration 400 / 1000: loss 2.290871
# iteration 500 / 1000: loss 2.296921
# iteration 600 / 1000: loss 2.283074
# iteration 700 / 1000: loss 2.296303
# iteration 800 / 1000: loss 2.293751
# iteration 900 / 1000: loss 2.293344
# learning_rate:  0.001  ;batch_size : 512 reg : 45  ;Validation accuracy:  0.175
# iteration 0 / 1000: loss 2.227395
# iteration 100 / 1000: loss 1.959170
# iteration 200 / 1000: loss 1.906638
# iteration 300 / 1000: loss 1.765346
# iteration 400 / 1000: loss 1.657225
# iteration 500 / 1000: loss 1.611768
# iteration 600 / 1000: loss 1.608411
# iteration 700 / 1000: loss 1.696661
# iteration 800 / 1000: loss 1.611245
# iteration 900 / 1000: loss 1.593366
# learning_rate:  0.001  ;batch_size : 512 reg : 0.5  ;Validation accuracy:  0.472
# iteration 0 / 1000: loss 1.505773
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:111: RuntimeWarning: divide by zero encountered in log
#   loss = -np.log(loss).sum()
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:107: RuntimeWarning: overflow encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)   # 数值稳定性
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:107: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)   # 数值稳定性
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:83: RuntimeWarning: invalid value encountered in greater
#   Z1_relu = (Z1 > 0) * Z1      # 没有这个激活函数准确度保证不了
# E:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:135: RuntimeWarning: invalid value encountered in greater
#   dZ1 = (Z1 > 0) * dZ1                 	# 反Relu
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py:275: RuntimeWarning: invalid value encountered in greater
#   A1 = (A1 > 0) * A1
# learning_rate:  0.009  ;batch_size : 64 reg : 0.25  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 64 reg : 35  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 64 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 64 reg : 45  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 64 reg : 0.5  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 0.25  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 35  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 45  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 128 reg : 0.5  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 0.25  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 35  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 0  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 45  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# learning_rate:  0.009  ;batch_size : 256 reg : 0.5  ;Validation accuracy:  0.087
# iteration 0 / 1000: loss nan
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-b137ae141436> in <module>()
#      36                         num_iters=1000, batch_size=bs,
#      37                         learning_rate=lr , learning_rate_decay=0.95,
# ---> 38                         reg=reg, verbose=True)
#      39
#      40             # Predict on the validation set
#
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, verbose)
#     203
#     204             # Compute loss and gradients using the current minibatch
# --> 205             loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
#     206             loss_history.append(loss)
#     207
#
# D:\Git\cs231n-better\assignment1\cs231n\classifiers\neural_net.py in loss(self, X, y, reg)
#     136
#     137         dW1 = np.dot(X.T, dZ1) / N
# --> 138         dW1 += 2 * reg * W1
#     139
#     140         db1 = np.sum(dZ1, axis=0, keepdims=True) / N
#
# KeyboardInterrupt:

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*:
#
# *Your explanation:*
